# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshini-Anand/Nunnariacademy_Datasciencewithaibootcamp/blob/main/Nunnari_DSwithAI_bootcamp_exercise_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **python basic exercises**

# %% [markdown]
# **Variables**

# %%
name = " Varshini "
print(name)
# Out:
#  Varshini

# %%
a = 10
b = 20
a, b = b, a
print(a, b)
# Out:
# 20 10

# %%
x, y, z = 1, 2, 3
print(x + y + z)
# Out:
# 6

# %%
value = 100
print(value)
value = 200
print(value)
# Out:
# 100
# 200

# %%
temp = 50
del temp

# %% [markdown]
# **Data types**

# %%
i, f, s, b = 10, 10.5, "Hi", True
print(type(i), type(f), type(s), type(b))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
print(type(3.14), type("Hello"), type(True), type(0))
# Out:
# <class 'float'> <class 'str'> <class 'bool'> <class 'int'>

# %%
x = 9
print(isinstance(x, int))
# Out:
# True

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %%
large_int = 10**20
small_float = 1e-10
print(large_int, small_float)
# Out:
# 100000000000000000000 1e-10

# %% [markdown]
# **Type conversion**

# %%
print(int("123") + 7)
# Out:
# 130

# %%
print(int(9.99))
# Out:
# 9

# %%
print(bool(0), bool(1))
# Out:
# False True

# %%
print(int(True), int(False))
# Out:
# 1 0

# %%
num = float(input("Enter a number: "))
print(num * 2)
# Out:
# Enter a number: 4
# 8.0

# %%
# int("hello")  # Raises a ValueError: invalid literal for int()

# %% [markdown]
# **String Manipulation**

# %%
s = "Hello, World!"
print(s.upper(), s.lower())
# Out:
# HELLO, WORLD! hello, world!

# %%
print(len("Python Programming"))
# Out:
# 18

# %%
s = "Hello, World!"
print(s[7:12])
# Out:
# World

# %%
print(len("Python Programming"))
# Out:
# 18

# %%
s = "Hello, World!"
print(s[7:12])
# Out:
# World

# %%
print("abcdef"[::-1])
# Out:
# fedcba

# %%
print("nan" in "banana")
# Out:
# True

# %%
print("This is a bad day".replace("bad", "good"))
# Out:
# This is a good day

# %%
print("  hello  ".strip())
# Out:
# hello

# %%
print("apple, banana, cherry".split(", "))
# Out:
# ['apple', 'banana', 'cherry']

# %%
print("banana".count("a"))
# Out:
# 3

# %%
print("Python123".isalnum())
# Out:
# True

# %% [markdown]
# **String-Formatting**

# %%
name, age = "John", 25
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is John and I am 25 years old

# %%
print("The price is {} dollars".format(49.99))
# Out:
# The price is 49.99 dollars

# %%
print(f"{3.14159:.2f}")
# Out:
# 3.14

# %%
print(f"{7:03}")
# Out:
# 007

# %%
print(f"{5} x {3} = {5*3}")
# Out:
# 5 x 3 = 15

# %%
print(f"{'Name':<10} {'Score':<5}")
print(f"{'Alice':<10} {95:<5}")
# Out:
# Name       Score
# Alice      95

# %% [markdown]
# **Python lists**

# %%
fruits = ["apple", "banana", "cherry", "date", "elderberry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'date', 'elderberry']

# %%
nums = [10, 20, 30, 40, 50]
print(nums[0], nums[-1])
# Out:
# 10 50

# %%
fruits.append("fig")

# %%
nums.insert(2, 99)

# %%
fruits.remove("banana")

# %%
l = [5, 2, 8, 1, 9]
l.sort()  # Ascending
l.sort(reverse=True)  # Descending

# %%
l = [3, 7, 1, 9, 4]
print(len(l), max(l), min(l))
# Out:
# 5 9 1

# %%
l = [0, 1, 2, 3, 4, 5, 6]
print(l[2:5])
# Out:
# [2, 3, 4]

# %%
orig = [1, 2, 3]
copy_list = orig.copy()
copy_list.append(4)
print(orig, copy_list)
# Out:
# [1, 2, 3] [1, 2, 3, 4]

# %%
l1, l2 = [1, 2, 3], [4, 5, 6]
merged = l1 + l2
print(merged)
# Out:
# [1, 2, 3, 4, 5, 6]
